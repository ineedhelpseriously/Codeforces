# %% [markdown]
# Faster I/O

# %%
#For smaller inputs

import sys
input=sys.stdin.readline

# %%
#For larger inputs

import io,os
input=io.ByteIO(os.read(0,os.fstat(0).st_size)).readline

# %%
#Egs with storing input:
import sys

a=int(sys.stdin.readline())

b=list(map(int,sys.stdin.readline().split()))

# %%
#Output:

sys.stdout.write(a+'\n')

# %%
#combination:
import sys

n=list(map(int,sys.stdin.readline().split()))
target=sys.stdin.readline()
sys.stdout.write(int(n.count(target)))

# %% [markdown]
# Loops and conditions

# %%
arr=[1,2,3,4,5]

# %%
s=0
for i in arr:
    s+=i

print(s)
# Out:
# 15

# %%
sum(arr)
# Out:
# 15

# %%
print(
    min(arr),
    max(arr),
    any(arr),
    all(arr)
    )
# Out:
# 1 5 True True

# %%
l=[1,2,3,4,-1,0,-2,-3]
print(any(ele>0 for ele in l))
print(all(ele>0 for ele in l))
# Out:
# True
# False

# %%
b=[1,2,3,4]
print(b)
# Out:
# [1, 2, 3, 4]

# %%
a=b.pop(-1)

# %%
print(b,a)
# Out:
# [1, 2, 3] 4
